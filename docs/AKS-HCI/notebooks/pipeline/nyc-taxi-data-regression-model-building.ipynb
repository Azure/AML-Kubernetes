# %% [markdown]
# Copyright (c) Microsoft Corporation. All rights reserved.
# Licensed under the MIT License.

# %% [markdown]
# # Linear Regression for NYC Taxi Datasets with AzureML Pipelines
#
# In this notebook, you learn how to prepare data for regression modeling. You run various transformations to filter and combine two different NYC taxi datasets
# using [Azure Machine Learning Pipelines](https://aka.ms/aml-pipelines). After data process steps, you add a final custom training step to train a regression model.  The trained model then registered to AzureML workspace.

# %% [markdown]
# ## Prerequisites
#
# * [Setup Azure Arc-enabled Machine Learning Training and Inferencing on AKS on Azure Stack HCI](https://github.com/Azure/AML-Kubernetes/tree/master/docs/AKS-HCI/AML-ARC-Compute.md)
#
# * Last but not least, you need to be able to run a Notebook. (azureml-core, azureml-opendatasets, numpy, matplotlib, requests are required)
#
#    If you are using an Azure Machine Learning Notebook VM, you are all set. Otherwise, make sure you go through the configuration Notebook located at [here](https://github.com/Azure/MachineLearningNotebooks) first. This sets you up with a working config file that has information on your workspace, subscription id, etc.

# %% [markdown]
# ## Initialize AzureML workspace
#
# Initialize a [Workspace](https://docs.microsoft.com/azure/machine-learning/service/concept-azure-machine-learning-architecture#workspace) object from the existing workspace you created in the Prerequisites step. `Workspace.from_config()` creates a workspace object from the details stored in `config.json`.
#
# If you haven't done already please go to `config.json` file and fill in your workspace information.

# %%
from azureml.core.workspace import Workspace,  ComputeTarget
from azureml.exceptions import ComputeTargetException

ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep='\n')
# Out:
# Warning: Falling back to use azure cli login credentials.
# If you run your code in unattended mode, i.e., where you can't give a user input, then we recommend to use ServicePrincipalAuthentication or MsiAuthentication.
# Please refer to aka.ms/aml-notebook-auth for different authentication mechanisms in azureml-sdk.
# Workspace name: amlarc-sample-test-ws-eastus
# Azure region: eastus
# Subscription id: 86204643-5a96-427b-b6bb-b35b2bd6e6ce
# Resource group: AKS-HCI2

# %% [markdown]
# ## Download data for regression modeling
#
# First, you will prepare data for regression modeling. you will leverage the convenience of Azure Open Datasets. Perform `pip install azureml-opendatasets` to get the open dataset package.  The Open Datasets package contains a class representing each data source (NycTlcGreen and NycTlcYellow) to easily filter date parameters before downloading.
#
#
# ### Fetch data
# Begin by creating a dataframe to hold the taxi data. When working in a non-Spark environment, Open Datasets only allows downloading one month of data at a time with certain classes to avoid MemoryError with large datasets. To download a year of taxi data, iteratively fetch one month at a time, and before appending it to green_df_raw, randomly sample 500 records from each month to avoid bloating the dataframe. Then preview the data. To keep this process short, we are sampling data of only 1 month.

# %%
from azureml.opendatasets import NycTlcGreen, NycTlcYellow
import pandas as pd
from datetime import datetime
from dateutil.relativedelta import relativedelta

green_df_raw = pd.DataFrame([])
start = datetime.strptime("1/1/2016","%m/%d/%Y")
end = datetime.strptime("1/31/2016","%m/%d/%Y")

number_of_months = 1
sample_size = 5000

for sample_month in range(number_of_months):
    temp_df_green = NycTlcGreen(start + relativedelta(months=sample_month), end + relativedelta(months=sample_month)) \
        .to_pandas_dataframe()
    green_df_raw = green_df_raw.append(temp_df_green.sample(sample_size))
# Out:
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmp2riuqlb1\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\green\puYear=2016\puMonth=1\part-00119-tid-4753095944193949832-fee7e113-666d-4114-9fcb-bcd3046479f3-2689-1.c000.snappy.parquet

# %%
yellow_df_raw = pd.DataFrame([])
start = datetime.strptime("1/1/2016","%m/%d/%Y")
end = datetime.strptime("1/31/2016","%m/%d/%Y")

sample_size = 500

for sample_month in range(number_of_months):
    temp_df_yellow = NycTlcYellow(start + relativedelta(months=sample_month), end + relativedelta(months=sample_month)) \
        .to_pandas_dataframe()
    yellow_df_raw = yellow_df_raw.append(temp_df_yellow.sample(sample_size))
# Out:
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00000-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426339-90.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00001-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426336-89.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00002-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426334-91.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00003-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426340-87.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00004-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426331-88.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00005-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426324-89.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00006-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426326-88.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00007-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426332-90.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00008-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426341-90.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00009-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426325-88.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00010-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426335-89.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00011-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426338-89.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00012-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426337-89.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00013-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426327-89.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00014-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426330-90.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00015-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426342-89.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00016-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426328-88.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00017-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426323-90.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00018-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426329-90.c000.snappy.parquet
# [Info] read from C:\Users\jiadu\AppData\Local\Temp\tmptfo2y6qe\https%3A\%2Fazureopendatastorage.azurefd.net\nyctlc\yellow\puYear=2016\puMonth=1\part-00019-tid-8898858832658823408-a1de80bd-eed3-4d11-b9d4-fa74bfbd47bc-426333-88.c000.snappy.parquet

# %% [markdown]
# ### See the data

# %%
from IPython.display import display

display(green_df_raw.head(5))
display(yellow_df_raw.head(5))
# Out:
#          vendorID  lpepPickupDatetime lpepDropoffDatetime  passengerCount  \
# 405733          1 2016-01-04 20:32:02 2016-01-04 20:37:52               1
# 719159          2 2016-01-30 10:22:19 2016-01-30 10:28:59               1
# 1250163         2 2016-01-15 09:49:29 2016-01-15 10:16:30               1
# 324106          2 2016-01-28 13:10:07 2016-01-28 13:23:29               1
# 1064446         2 2016-01-25 17:31:42 2016-01-25 17:53:06               1
#
#          tripDistance puLocationId doLocationId  pickupLongitude  \
# 405733           0.50         None         None       -73.895576
# 719159           2.66         None         None       -73.921677
# 1250163          6.26         None         None       -73.974739
# 324106           5.13         None         None       -73.844246
# 1064446          3.30         None         None       -73.949142
#
#          pickupLatitude  dropoffLongitude  ...  paymentType  fareAmount extra  \
# 405733        40.746532        -73.889244  ...            1         4.5   0.5
# 719159        40.766869        -73.893593  ...            1        10.0   0.0
# 1250163       40.687874        -73.969604  ...            1        24.5   0.0
# 324106        40.721375        -73.753830  ...            2        17.0   0.0
# 1064446       40.785168        -73.938004  ...            1        15.0   1.0
#
#          mtaTax  improvementSurcharge  tipAmount  tollsAmount ehailFee  \
# 405733      0.5                   0.3       0.00          0.0      NaN
# 719159      0.5                   0.3       1.00          0.0      NaN
# 1250163     0.5                   0.3       5.06          0.0      NaN
# 324106      0.5                   0.3       0.00          0.0      NaN
# 1064446     0.5                   0.3       3.36          0.0      NaN
#
#          totalAmount  tripType
# 405733          5.80       1.0
# 719159         11.80       1.0
# 1250163        30.36       1.0
# 324106         17.80       1.0
# 1064446        20.16       1.0
#
# [5 rows x 23 columns]
#        vendorID  tpepPickupDateTime tpepDropoffDateTime  passengerCount  \
# 40494         1 2016-01-03 23:54:43 2016-01-04 00:07:17               1
# 38392         1 2016-01-03 17:13:52 2016-01-03 17:38:07               2
# 74255         1 2016-01-09 09:08:09 2016-01-09 09:17:40               1
# 270873        2 2016-01-09 03:21:37 2016-01-09 03:48:56               1
# 70525         1 2016-01-09 00:52:18 2016-01-09 00:58:42               2
#
#         tripDistance puLocationId doLocationId   startLon   startLat  \
# 40494           3.60         None         None -73.986992  40.760986
# 38392           5.70         None         None -73.994987  40.749947
# 74255           4.60         None         None -73.944206  40.792145
# 270873         10.85         None         None -73.984688  40.763969
# 70525           0.90         None         None -73.985779  40.738205
#
#            endLon  ...  rateCodeId  storeAndFwdFlag paymentType fareAmount  \
# 40494  -73.953041  ...           1                N           2       13.5
# 38392  -74.008118  ...           1                N           1       21.0
# 74255  -73.936882  ...           1                N           2       15.0
# 270873 -73.972176  ...           1                N           1       33.0
# 70525  -74.001984  ...           1                N           2        6.0
#
#         extra  mtaTax  improvementSurcharge tipAmount  tollsAmount  \
# 40494     0.5     0.5                   0.3      0.00         0.00
# 38392     0.0     0.5                   0.3      1.50         0.00
# 74255     0.0     0.5                   0.3      0.00         0.00
# 270873    0.5     0.5                   0.3      7.97         5.54
# 70525     0.5     0.5                   0.3      0.00         0.00
#
#         totalAmount
# 40494         14.80
# 38392         23.30
# 74255         15.80
# 270873        47.81
# 70525          7.30
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Save data locally

# %%
import os
dataDir = "data"

if not os.path.exists(dataDir):
    os.mkdir(dataDir)

greenDir = dataDir + "/green"
yellowDir = dataDir + "/yellow"

if not os.path.exists(greenDir):
    os.mkdir(greenDir)
    
if not os.path.exists(yellowDir):
    os.mkdir(yellowDir)
    
greenTaxiData = greenDir + "/unprepared.csv"
yellowTaxiData = yellowDir + "/unprepared.csv"

green_df_raw.to_csv(greenTaxiData, index=False)
yellow_df_raw.to_csv(yellowTaxiData, index=False)

print("Data written to local folder.")
# Out:
# Data written to local folder.

# %% [markdown]
# ## Prepare the dataset
#
# Your next step is to upload these files to datastore of the workspace, and then registered as dataset in the workspace.
#
# "datastore_name" is the name of the datastore you setup in [this step](https://github.com/Azure/AML-Kubernetes/blob/master/docs/ASH/Train-AzureArc.md).
#
# Upload and dataset registration take less than 1 min.

# %%
from azureml.core import Workspace, Datastore, Dataset

# datastore_name = "<NAME_OF_ASH_HOSTED_AML_DATASTORE>"
def_data_store = ws.get_default_datastore()
datastore_name = def_data_store.name
datastore =  Datastore.get(ws, datastore_name)

dataDir = "data"
greenDir, yellowDir  = dataDir + "/green", dataDir + "/yellow"
greenTaxiData, yellowTaxiData = greenDir + "/unprepared.csv", yellowDir + "/unprepared.csv"

datastore.upload_files([greenTaxiData], 
                           target_path = 'green', 
                           overwrite = True, 
                           show_progress = True)

datastore.upload_files([yellowTaxiData], 
                           target_path = 'yellow', 
                           overwrite = True, 
                           show_progress = True)

print("Upload calls completed.")

# register datasets

dataset_name,  target_path = 'green_taxi_data_o_file', 'green/unprepared.csv'
datastore_paths = [(datastore, target_path)]
green_taxi_data = Dataset.File.from_files(path=datastore_paths)
green_taxi_data.register(ws, dataset_name)

dataset_name,  target_path = 'yellow_taxi_data_o_file', 'yellow/unprepared.csv'
datastore_paths = [(datastore, target_path)]
yellow_taxi_data = Dataset.File.from_files(path=datastore_paths)
yellow_taxi_data.register(ws, dataset_name)
# Out:
# Uploading an estimated of 1 files
# Uploading data/green/unprepared.csv
# Uploaded data/green/unprepared.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
# Uploading an estimated of 1 files
# Uploading data/yellow/unprepared.csv
# Uploaded data/yellow/unprepared.csv, 1 files out of an estimated total of 1
# Uploaded 1 files
# Upload calls completed.
# {
#   "source": [
#     "('workspaceblobstore', 'yellow/unprepared.csv')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "de1355e1-0ca6-44b4-a685-f9ab9a1876f8",
#     "name": "yellow_taxi_data_o_file",
#     "version": 1,
#     "workspace": "Workspace.create(name='amlarc-sample-test-ws-eastus', subscription_id='86204643-5a96-427b-b6bb-b35b2bd6e6ce', resource_group='AKS-HCI2')"
#   }
# }

# %% [markdown]
# ## Setup compute target
#
# Find the attach name for the Arc enabled  Azure Stack Hub kubernetes cluster in your AzureML workspace to create a ComputeTarget:
#
# attach_name is the attached name for your ASH cluster you setup in [this step](https://github.com/Azure/AML-Kubernetes/blob/master/docs/ASH/AML-ARC-Compute.md)

# %%
from azureml.core.compute import KubernetesCompute

# attach_name = "<NAME_OF_AML_ATTACHED_COMPUTE_OF_YOUR_ASH_CLUSTER>"
attach_name = "arc-compute3"
arcK_compute = KubernetesCompute(ws, attach_name)
# Out:
# Class KubernetesCompute: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %% [markdown]
# ### Define RunConfig for the compute target
# We will also use `pandas`, `scikit-learn`,  `pyarrow` for the pipeline steps. Defining the `runconfig` for that.

# %%
from azureml.core.runconfig import RunConfiguration
from azureml.core.conda_dependencies import CondaDependencies

# Create a new runconfig object
aml_run_config = RunConfiguration()

# Use the arcK_compute you created above. 
aml_run_config.target = arcK_compute

# Enable Docker
aml_run_config.environment.docker.enabled = True

# Use conda_dependencies.yml to create a conda environment in the Docker image for execution
aml_run_config.environment.python.user_managed_dependencies = False

# Specify CondaDependencies obj, add necessary packages
aml_run_config.environment.python.conda_dependencies = CondaDependencies.create(
    conda_packages=['pandas','scikit-learn'], 
    pip_packages=['azureml-sdk', 'pyarrow'])

print ("Run configuration created.")
# Out:
# 'enabled' is deprecated. Please use the azureml.core.runconfig.DockerConfiguration object with the 'use_docker' param instead.
# Run configuration created.

# %% [markdown]
# ## Processing data with pipeline steps
#
# The data process includes following pipeline steps implemented as PythonScriptStep:
#
# 1. Cleanse Green Taxi Data
# 2. Cleanse Yellow Taxi Data
# 3. Merge cleansed Green and Yellow Taxi Data
# 4. Filter Taxi Data
# 5. Normalize Taxi Data
# 6. Transform Taxi Data
# 7. Train Test Data Split

# %% [markdown]
# ### Cleanse Taxi Data
#
# Here a set of "useful" columns for both Green and Yellow taxi data are defined:

# %%
useful_columns = str(["cost", "distance", "dropoff_datetime", "dropoff_latitude", 
                      "dropoff_longitude", "passengers", "pickup_datetime", 
                      "pickup_latitude", "pickup_longitude", "store_forward", "vendor"]).replace(",", ";")

# %% [markdown]
# #### Cleanse Green taxi data

# %%
from azureml.pipeline.core import PipelineData
from azureml.data import OutputFileDatasetConfig
from azureml.pipeline.steps import PythonScriptStep
import os

# python scripts folder
prepare_data_folder = './scripts/prepdata'

# rename columns as per Azure Machine Learning NYC Taxi tutorial

green_columns = {
        "vendorID": "vendor",
        "lpepPickupDatetime": "pickup_datetime",
        "lpepDropoffDatetime": "dropoff_datetime",
        "storeAndFwdFlag": "store_forward",
        "pickupLongitude": "pickup_longitude",
        "pickupLatitude": "pickup_latitude",
        "dropoffLongitude": "dropoff_longitude",
        "dropoffLatitude": "dropoff_latitude",
        "passengerCount": "passengers",
        "fareAmount": "cost",
        "tripDistance": "distance"
    }

green_columns_key = str(list(green_columns.keys())).replace(",", ";")
green_columns_value = str(list(green_columns.values())).replace(",", ";")
    
# Define output after cleansing step
dest = (datastore, None)
cleansed_green_data = OutputFileDatasetConfig(name="cleansed_green_data", destination=dest).as_upload(overwrite=False)

print('Cleanse script is in {}.'.format(os.path.realpath(prepare_data_folder)))

# cleansing step creation
# See the cleanse.py for details
cleansingStepGreen = PythonScriptStep(
    name="Cleanse Green Taxi Data",
    script_name="cleanse.py", 
    arguments=["--data-path", green_taxi_data.as_named_input('raw_data').as_mount(),
        "--useful_columns", useful_columns,
               "--columns_key", green_columns_key,
                "--columns_value", green_columns_value,
               "--output_cleanse", cleansed_green_data],
    outputs=[cleansed_green_data],
    compute_target=arcK_compute,
    runconfig=aml_run_config,
    source_directory=prepare_data_folder,
    allow_reuse=True
)

print("cleansingStepGreen created.")
# Out:
# Cleanse script is in E:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\scripts\prepdata.
# cleansingStepGreen created.

# %% [markdown]
# #### Cleanse Yellow taxi data

# %%
yellow_columns = {
    "vendorID": "vendor",
    "tpepPickupDateTime": "pickup_datetime",
    "tpepDropoffDateTime": "dropoff_datetime",
    "storeAndFwdFlag": "store_forward",
    "startLon": "pickup_longitude",
    "startLat": "pickup_latitude",
    "endLon": "dropoff_longitude",
    "endLat": "dropoff_latitude",
    "passengerCount": "passengers",
    "fareAmount": "cost",
    "tripDistance": "distance"
}

yellow_columns_key = str(list(yellow_columns.keys())).replace(",", ";")
yellow_columns_value = str(list(yellow_columns.values())).replace(",", ";")
    
# Define output after cleansing step
dest = (datastore, None)
cleansed_yellow_data = OutputFileDatasetConfig(name="cleansed_yellow_data", destination=dest).as_upload(overwrite=False)

# cleansing step creation
# See the cleanse.py for details about input and output
cleansingStepYellow = PythonScriptStep(
    name="Cleanse Yellow Taxi Data",
    script_name="cleanse.py", 
    arguments=["--data-path", yellow_taxi_data.as_named_input('raw_data').as_mount(),
        "--useful_columns", useful_columns,
               "--columns_key", yellow_columns_key,
                "--columns_value", yellow_columns_value,
               "--output_cleanse", cleansed_yellow_data],
    compute_target=arcK_compute,
    runconfig=aml_run_config,
    source_directory=prepare_data_folder,
    allow_reuse=True
)

print("cleansingStepYellow created.")
# Out:
# cleansingStepYellow created.

# %% [markdown]
# ### Merge cleansed Green and Yellow datasets
#
# Create a single data source by merging the cleansed versions of Green and Yellow taxi data.

# %%
# Define output after cleansing step
merged_data = OutputFileDatasetConfig(name="merged_data", destination=dest).as_upload(overwrite=False)


print('Merge script is in {}.'.format(os.path.realpath(prepare_data_folder)))

# merging step creation
# See the merge.py for details about input and output
mergingStep = PythonScriptStep(
    name="Merge Taxi Data",
    script_name="merge.py", 
    arguments=["--green_data_path", cleansed_green_data.as_input(),
               "--yellow_data_path", cleansed_yellow_data.as_input(),
        "--output_merge", merged_data],
    compute_target=arcK_compute,
    runconfig=aml_run_config,
    source_directory=prepare_data_folder,
    allow_reuse=True
)

print("mergingStep created.")
# Out:
# Merge script is in E:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\scripts\prepdata.
# mergingStep created.

# %% [markdown]
# ### Filter taxi data
#
# This step filters out coordinates for locations that are outside the city border. We use a TypeConverter object to change the latitude and longitude fields to decimal type.

# %%
# Define output after merging step
filtered_data = OutputFileDatasetConfig(name="filtered_data", destination=dest).as_upload(overwrite=False)

print('Filter script is in {}.'.format(os.path.realpath(prepare_data_folder)))

# filter step creation
# See the filter.py for details about input and output
filterStep = PythonScriptStep(
    name="Filter Taxi Data",
    script_name="filter.py", 
    arguments=["--data-path", merged_data.as_input(),
        "--output_filter", filtered_data],
    compute_target=arcK_compute,
    runconfig = aml_run_config,
    source_directory=prepare_data_folder,
    allow_reuse=True
)

print("FilterStep created.")
# Out:
# Filter script is in E:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\scripts\prepdata.
# FilterStep created.

# %% [markdown]
# ### Normalize taxi data
# In this step, pickup and dropoff datetime values are splitted into the respective date and time columns.  Then rename the columns to meaningful names.

# %%
# Define output after normalize step
normalized_data = OutputFileDatasetConfig(name="normalized_data", destination=dest).as_upload(overwrite=False)

print('Normalize script is in {}.'.format(os.path.realpath(prepare_data_folder)))

# normalize step creation
# See the normalize.py for details about input and output
normalizeStep = PythonScriptStep(
    name="Normalize Taxi Data",
    script_name="normalize.py", 
    arguments=["--data-path", filtered_data.as_input(),
        "--output_normalize", normalized_data],
    compute_target=arcK_compute,
    runconfig = aml_run_config,
    source_directory=prepare_data_folder,
    allow_reuse=True
)

print("normalizeStep created.")
# Out:
# Normalize script is in E:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\scripts\prepdata.
# normalizeStep created.

# %% [markdown]
# ### Transform taxi data
# Transform the normalized taxi data to final required format. This steps does the following:
#
# - Split the pickup and dropoff date further into the day of the week, day of the month, and month values.
# - To get the day of the week value, uses the derive_column_by_example() function. The function takes an array parameter of example objects that define the input data, and the preferred output. The function automatically determines the preferred transformation. For the pickup and dropoff time columns, split the time into the hour, minute, and second by using the split_column_by_example() function with no example parameter.
# - After new features are generated, use the drop_columns() function to delete the original fields as the newly generated features are preferred.
# - Rename the rest of the fields to use meaningful descriptions.

# %%
# Define output after transform step
transformed_data = OutputFileDatasetConfig(name="transformed_data", destination=dest).as_upload(overwrite=False)

print('Transform script is in {}.'.format(os.path.realpath(prepare_data_folder)))

# transform step creation
# See the transform.py for details about input and output
transformStep = PythonScriptStep(
    name="Transform Taxi Data",
    script_name="transform.py", 
    arguments=["--data-path", normalized_data.as_input(),
        "--output_transform", transformed_data],
    compute_target=arcK_compute,
    runconfig = aml_run_config,
    source_directory=prepare_data_folder,
    allow_reuse=True
)

print("transformStep created.")
# Out:
# Transform script is in E:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\scripts\prepdata.
# transformStep created.

# %% [markdown]
# ### Split the data into train and test sets
#
# This function segregates the data into dataset for model training and dataset for testing.

# %%
train_model_folder = './scripts/trainmodel'

# train and test splits output
output_split_train = OutputFileDatasetConfig(name="output_split_train", destination=dest).as_upload(overwrite=False)
output_split_test = OutputFileDatasetConfig(name="output_split_test", destination=dest).as_upload(overwrite=False)

output_split_test.register_on_complete(name='nyc_taxi_test_set', 
                                       description='test set  from Train Test Data Split')

print('Data spilt script is in {}.'.format(os.path.realpath(train_model_folder)))

# test train split step creation
# See the train_test_split.py for details about input and output
testTrainSplitStep = PythonScriptStep(
    name="Train Test Data Split",
    script_name="train_test_split.py", 
    arguments=["--data-path", transformed_data.as_input(),
        "--output_split_train", output_split_train,
               "--output_split_test", output_split_test],
    compute_target=arcK_compute,
    runconfig = aml_run_config,
    source_directory=train_model_folder,
    allow_reuse=True
)

print("testTrainSplitStep created.")
# Out:
# Data spilt script is in E:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\scripts\trainmodel.
# testTrainSplitStep created.

# %% [markdown]
# ### Define a custom training step

# %%
train_step = PythonScriptStep(
        name="train_step",
        script_name="train_step.py",
        arguments=["--train_data_path", output_split_train.as_input(),
                   "--test_data_path", output_split_test.as_input(),
        ],
      
        compute_target=arcK_compute,
        runconfig=aml_run_config,
        source_directory=train_model_folder,
        allow_reuse=True
    )

print("train_step created.")
# Out:
# train_step created.

# %% [markdown]
# ## Create an experiement

# %%
from azureml.core import Experiment

experiment = Experiment(ws, 'NYCTaxi_Tutorial_Pipelines')

print("Experiment created")
# Out:
# Experiment created

# %% [markdown]
# ### Build and run the pipeline

# %%
from azureml.pipeline.core import Pipeline

pipeline_steps = [train_step]

pipeline = Pipeline(workspace = ws, steps=pipeline_steps)
print("Pipeline is built.")

pipeline_run = experiment.submit(pipeline, regenerate_outputs=False)

print("Pipeline submitted for execution.")

pipeline_run.wait_for_completion()
# Out:
# Pipeline is built.
# Created step train_step [732fe391][6a5373cd-fb70-44f9-9ea5-c10cdc1b12da], (This step will run and generate new outputs)
# Created step Train Test Data Split [8bc2e8d4][982a0907-98f9-498c-a0db-042e9bbd6514], (This step will run and generate new outputs)
# Created step Transform Taxi Data [0173ee30][6a15263a-d7d6-43b8-8d84-c1d542940dd9], (This step will run and generate new outputs)
# Created step Normalize Taxi Data [24bd4890][7696f53a-ef4f-47cf-a65c-cb13cd74e1e4], (This step will run and generate new outputs)
# Created step Filter Taxi Data [23aa11b1][70391ef1-d7ef-4a79-9286-74fb4f19cfc6], (This step will run and generate new outputs)
# Created step Merge Taxi Data [697c34df][3d9a07e1-e15c-448f-b38f-180f9ea07ab3], (This step will run and generate new outputs)
# Created step Cleanse Green Taxi Data [fe604d49][745dcc1e-612d-4406-b63a-87dc5cd8de02], (This step will run and generate new outputs)Created step Cleanse Yellow Taxi Data [7fc00336][9cb5e7b4-da00-425e-9bd3-9e7522a5c5e4], (This step will run and generate new outputs)
#
# Submitted PipelineRun ac2b6821-e275-4fe6-9649-7a74c96c9e4f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ac2b6821-e275-4fe6-9649-7a74c96c9e4f?wsid=/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourcegroups/AKS-HCI2/workspaces/amlarc-sample-test-ws-eastus&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# Pipeline submitted for execution.
# PipelineRunId: ac2b6821-e275-4fe6-9649-7a74c96c9e4f
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ac2b6821-e275-4fe6-9649-7a74c96c9e4f?wsid=/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourcegroups/AKS-HCI2/workspaces/amlarc-sample-test-ws-eastus&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# PipelineRun Status: Running
#
#
# StepRunId: 630ff845-c767-40cc-84ce-0487e0be32ee
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/630ff845-c767-40cc-84ce-0487e0be32ee?wsid=/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourcegroups/AKS-HCI2/workspaces/amlarc-sample-test-ws-eastus&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Cleanse Green Taxi Data ) Status: Running
#
# Streaming azureml-logs/20_image_build_log.txt
# =============================================
# 2021/11/24 05:26:25 Downloading source code...
# 2021/11/24 05:26:26 Finished downloading source code
# 2021/11/24 05:26:26 Creating Docker network: acb_default_network, driver: 'bridge'
# 2021/11/24 05:26:27 Successfully set up Docker network: acb_default_network
# 2021/11/24 05:26:27 Setting up Docker configuration...
# 2021/11/24 05:26:27 Successfully set up Docker configuration
# 2021/11/24 05:26:27 Logging in to registry: e6fafec881fb4906968577c5282597a0.azurecr.io
# 2021/11/24 05:26:28 Successfully logged into e6fafec881fb4906968577c5282597a0.azurecr.io
# 2021/11/24 05:26:28 Executing step ID: acb_step_0. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/24 05:26:28 Scanning for dependencies...
# 2021/11/24 05:26:28 Successfully scanned dependencies
# 2021/11/24 05:26:28 Launching container with name: acb_step_0
# Sending build context to Docker daemon  66.56kB
#
# Step 1/19 : FROM mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c: Pulling from azureml/openmpi3.1.2-ubuntu18.04
# feac53061382: Pulling fs layer
# 7dce5c8175d6: Pulling fs layer
# 0a1b9502ed8f: Pulling fs layer
# d187f505e8b8: Pulling fs layer
# c7a3c00b133d: Pulling fs layer
# 31b816123763: Pulling fs layer
# 37b899c2505c: Pulling fs layer
# abda0175e0e2: Pulling fs layer
# 19d6148ce542: Pulling fs layer
# d187f505e8b8: Waiting
# c7a3c00b133d: Waiting
# 31b816123763: Waiting
# 37b899c2505c: Waiting
# abda0175e0e2: Waiting
# 19d6148ce542: Waiting
# 0a1b9502ed8f: Verifying Checksum
# 0a1b9502ed8f: Download complete
# feac53061382: Verifying Checksum
# feac53061382: Download complete
# d187f505e8b8: Verifying Checksum
# d187f505e8b8: Download complete
# 31b816123763: Verifying Checksum
# 31b816123763: Download complete
# 37b899c2505c: Verifying Checksum
# 37b899c2505c: Download complete
# 7dce5c8175d6: Verifying Checksum
# 7dce5c8175d6: Download complete
# abda0175e0e2: Verifying Checksum
# abda0175e0e2: Download complete
# 19d6148ce542: Verifying Checksum
# 19d6148ce542: Download complete
# c7a3c00b133d: Verifying Checksum
# c7a3c00b133d: Download complete
# feac53061382: Pull complete
# 7dce5c8175d6: Pull complete
# 0a1b9502ed8f: Pull complete
# d187f505e8b8: Pull complete
# c7a3c00b133d: Pull complete
# 31b816123763: Pull complete
# 37b899c2505c: Pull complete
# abda0175e0e2: Pull complete
# 19d6148ce542: Pull complete
# Digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
# Status: Downloaded newer image for mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1@sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#  ---> 82e13edbc8db
# Step 2/19 : USER root
#  ---> Running in 30868b704f28
# Removing intermediate container 30868b704f28
#  ---> 142fefe31afb
# Step 3/19 : RUN mkdir -p $HOME/.cache
#  ---> Running in b0aac756ae26
# Removing intermediate container b0aac756ae26
#  ---> fbe75ad3e3eb
# Step 4/19 : WORKDIR /
#  ---> Running in e910707425f5
# Removing intermediate container e910707425f5
#  ---> 41c587515795
# Step 5/19 : COPY azureml-environment-setup/99brokenproxy /etc/apt/apt.conf.d/
#  ---> 7b80cd98acfe
# Step 6/19 : RUN if dpkg --compare-versions `conda --version | grep -oE '[^ ]+$'` lt 4.4.11; then conda install conda==4.4.11; fi
#  ---> Running in 0fa747b39b0e
# Removing intermediate container 0fa747b39b0e
#  ---> ce99f106d779
# Step 7/19 : COPY azureml-environment-setup/mutated_conda_dependencies.yml azureml-environment-setup/mutated_conda_dependencies.yml
#  ---> f6b334996b29
# Step 8/19 : RUN ldconfig /usr/local/cuda/lib64/stubs && conda env create -p /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7 -f azureml-environment-setup/mutated_conda_dependencies.yml && rm -rf "$HOME/.cache/pip" && conda clean -aqy && CONDA_ROOT_DIR=$(conda info --root) && rm -rf "$CONDA_ROOT_DIR/pkgs" && find "$CONDA_ROOT_DIR" -type d -name __pycache__ -exec rm -rf {} + && ldconfig
#  ---> Running in 23e53e764950
# Warning: you have pip-installed dependencies in your environment file, but you do not list pip itself as one of your conda dependencies.  Conda may not use the correct pip to install your packages, and they may end up in the wrong place.  Please add an explicit pip dependency.  I'm adding one for you, but still nagging you.
# Collecting package metadata (repodata.json): ...working...
# done
# Solving environment: ...working...
# done
#
# Downloading and Extracting Packages
#
# readline-7.0         | 387 KB    |            |   0%
# readline-7.0         | 387 KB    | ########## | 100%
# readline-7.0         | 387 KB    | ########## | 100%
#
# openssl-1.0.2u       | 3.1 MB    |            |   0%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
# openssl-1.0.2u       | 3.1 MB    | ########## | 100%
#
# ca-certificates-2020 | 128 KB    |            |   0%
# ca-certificates-2020 | 128 KB    | ########## | 100%
#
# certifi-2020.6.20    | 160 KB    |            |   0%
# certifi-2020.6.20    | 160 KB    | ########## | 100%
#
# joblib-0.17.0        | 205 KB    |            |   0%
# joblib-0.17.0        | 205 KB    | ########## | 100%
#
# threadpoolctl-2.1.0  | 16 KB     |            |   0%
# threadpoolctl-2.1.0  | 16 KB     | ########## | 100%
#
# mkl_random-1.1.0     | 369 KB    |            |   0%
# mkl_random-1.1.0     | 369 KB    | ########## | 100%
#
# python-dateutil-2.8. | 224 KB    |            |   0%
# python-dateutil-2.8. | 224 KB    | ########## | 100%
#
# scipy-1.5.2          | 18.5 MB   |            |   0%
# scipy-1.5.2          | 18.5 MB   | ##2        |  22%
# scipy-1.5.2          | 18.5 MB   | ###5       |  36%
# scipy-1.5.2          | 18.5 MB   | #####      |  50%
# scipy-1.5.2          | 18.5 MB   | #####9     |  59%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
# scipy-1.5.2          | 18.5 MB   | ########## | 100%
#
# pandas-1.1.3         | 10.5 MB   |            |   0%
# pandas-1.1.3         | 10.5 MB   | ##4        |  24%
# pandas-1.1.3         | 10.5 MB   | #####1     |  52%
# pandas-1.1.3         | 10.5 MB   | #######4   |  75%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
# pandas-1.1.3         | 10.5 MB   | ########## | 100%
#
# blas-1.0             | 6 KB      |            |   0%
# blas-1.0             | 6 KB      | ########## | 100%
#
# libffi-3.2.1         | 52 KB     |            |   0%
# libffi-3.2.1         | 52 KB     | ########## | 100%
#
# mkl-2019.4           | 204.1 MB  |            |   0%
# mkl-2019.4           | 204.1 MB  | 3          |   4%
# mkl-2019.4           | 204.1 MB  | 9          |   9%
# mkl-2019.4           | 204.1 MB  | #5         |  16%
# mkl-2019.4           | 204.1 MB  | ##1        |  22%
# mkl-2019.4           | 204.1 MB  | ##6        |  27%
# mkl-2019.4           | 204.1 MB  | ###1       |  32%
# mkl-2019.4           | 204.1 MB  | ###7       |  38%
# mkl-2019.4           | 204.1 MB  | ####5      |  45%
# mkl-2019.4           | 204.1 MB  | #####      |  51%
# mkl-2019.4           | 204.1 MB  | #####5     |  56%
# mkl-2019.4           | 204.1 MB  | #####9     |  60%
# mkl-2019.4           | 204.1 MB  | ######3    |  63%
# mkl-2019.4           | 204.1 MB  | ######8    |  69%
# mkl-2019.4           | 204.1 MB  | #######5   |  75%
# mkl-2019.4           | 204.1 MB  | ########   |  81%
# mkl-2019.4           | 204.1 MB  | ########5  |  86%
# mkl-2019.4           | 204.1 MB  | #########  |  91%
# mkl-2019.4           | 204.1 MB  | #########7 |  97%
#
# mkl-2019.4           | 204.1 MB  | ########## | 100%
#
# zlib-1.2.11          | 120 KB    |            |   0%
# zlib-1.2.11          | 120 KB    | ########## | 100%
#
# pip-20.2.4           | 2.0 MB    |            |   0%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
# pip-20.2.4           | 2.0 MB    | ########## | 100%
#
# intel-openmp-2020.2  | 947 KB    |            |   0%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
# intel-openmp-2020.2  | 947 KB    | ########## | 100%
#
# six-1.15.0           | 13 KB     |            |   0%
# six-1.15.0           | 13 KB     | ########## | 100%
#
# setuptools-50.3.0    | 891 KB    |            |   0%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
# setuptools-50.3.0    | 891 KB    | ########## | 100%
#
# sqlite-3.23.1        | 1.5 MB    |            |   0%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
# sqlite-3.23.1        | 1.5 MB    | ########## | 100%
#
# libgcc-ng-9.1.0      | 8.1 MB    |            |   0%
# libgcc-ng-9.1.0      | 8.1 MB    | #####2     |  52%
# libgcc-ng-9.1.0      | 8.1 MB    | #######3   |  73%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
# libgcc-ng-9.1.0      | 8.1 MB    | ########## | 100%
#
# xz-5.2.5             | 438 KB    |            |   0%
# xz-5.2.5             | 438 KB    | ########## | 100%
#
# numpy-1.19.1         | 20 KB     |            |   0%
# numpy-1.19.1         | 20 KB     | ########## | 100%
#
# ncurses-6.0          | 907 KB    |            |   0%
# ncurses-6.0          | 907 KB    | ########## | 100%
# ncurses-6.0          | 907 KB    | ########## | 100%
#
# mkl_fft-1.2.0        | 164 KB    |            |   0%
# mkl_fft-1.2.0        | 164 KB    | ########## | 100%
#
# numpy-base-1.19.1    | 5.2 MB    |            |   0%
# numpy-base-1.19.1    | 5.2 MB    | ##9        |  30%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
# numpy-base-1.19.1    | 5.2 MB    | ########## | 100%
#
# tk-8.6.10            | 3.2 MB    |            |   0%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
# tk-8.6.10            | 3.2 MB    | ########## | 100%
#
# libgfortran-ng-7.3.0 | 1.3 MB    |            |   0%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
# libgfortran-ng-7.3.0 | 1.3 MB    | ########## | 100%
#
# libedit-3.1          | 171 KB    |            |   0%
# libedit-3.1          | 171 KB    | ########## | 100%
#
# libstdcxx-ng-9.1.0   | 4.0 MB    |            |   0%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
# libstdcxx-ng-9.1.0   | 4.0 MB    | ########## | 100%
#
# scikit-learn-0.23.2  | 6.9 MB    |            |   0%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
# scikit-learn-0.23.2  | 6.9 MB    | ########## | 100%
#
# pytz-2020.1          | 239 KB    |            |   0%
# pytz-2020.1          | 239 KB    | ########## | 100%
# pytz-2020.1          | 239 KB    | ########## | 100%
#
# mkl-service-2.3.0    | 208 KB    |            |   0%
# mkl-service-2.3.0    | 208 KB    | ########## | 100%
#
# wheel-0.35.1         | 36 KB     |            |   0%
# wheel-0.35.1         | 36 KB     | ########## | 100%
#
# python-3.6.2         | 27.0 MB   |            |   0%
# python-3.6.2         | 27.0 MB   | ###9       |  39%
# python-3.6.2         | 27.0 MB   | #######8   |  78%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# python-3.6.2         | 27.0 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Installing pip dependencies: ...working...
# Ran pip subprocess with arguments:
# ['/azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/bin/python', '-m', 'pip', 'install', '-U', '-r', '/azureml-environment-setup/condaenv.4qq4esib.requirements.txt']
# Pip subprocess output:
# Collecting azureml-sdk~=1.34.0
#   Downloading azureml_sdk-1.34.0-py3-none-any.whl (4.5 kB)
# Collecting pyarrow
#   Downloading pyarrow-6.0.1-cp36-cp36m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (25.6 MB)
# Collecting azureml-pipeline~=1.34.0
#   Downloading azureml_pipeline-1.34.0-py3-none-any.whl (3.7 kB)
# Collecting azureml-core~=1.34.0
#   Downloading azureml_core-1.34.0-py3-none-any.whl (2.2 MB)
# Collecting azureml-train-core~=1.34.0
#   Downloading azureml_train_core-1.34.0-py3-none-any.whl (8.6 MB)
# Collecting azureml-dataset-runtime[fuse]~=1.34.0
#   Downloading azureml_dataset_runtime-1.34.0-py3-none-any.whl (3.5 kB)
# Collecting azureml-train-automl-client~=1.34.0
#   Downloading azureml_train_automl_client-1.34.0-py3-none-any.whl (130 kB)
# Requirement already satisfied, skipping upgrade: numpy>=1.16.6 in /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib/python3.6/site-packages (from pyarrow->-r /azureml-environment-setup/condaenv.4qq4esib.requirements.txt (line 2)) (1.19.1)
# Collecting azureml-pipeline-steps~=1.34.0
#   Downloading azureml_pipeline_steps-1.34.0-py3-none-any.whl (70 kB)
# Collecting azureml-pipeline-core~=1.34.0
#   Downloading azureml_pipeline_core-1.34.0-py3-none-any.whl (312 kB)
# Collecting urllib3<=1.26.6,>=1.23
#   Downloading urllib3-1.26.6-py2.py3-none-any.whl (138 kB)
# Collecting contextlib2<22.0.0
#   Downloading contextlib2-21.6.0-py2.py3-none-any.whl (13 kB)
# Collecting azure-graphrbac<1.0.0,>=0.40.0
#   Downloading azure_graphrbac-0.61.1-py2.py3-none-any.whl (141 kB)
# Collecting requests<3.0.0,>=2.19.1
#   Downloading requests-2.26.0-py2.py3-none-any.whl (62 kB)
# Collecting azure-common<2.0.0,>=1.1.12
#   Downloading azure_common-1.1.27-py2.py3-none-any.whl (12 kB)
# Collecting azure-mgmt-containerregistry>=2.0.0
#   Downloading azure_mgmt_containerregistry-8.2.0-py2.py3-none-any.whl (928 kB)
# Collecting pathspec<1.0.0
#   Downloading pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting azure-mgmt-storage<16.0.0,>=1.5.0
#   Downloading azure_mgmt_storage-11.2.0-py2.py3-none-any.whl (547 kB)
# Collecting ndg-httpsclient<=0.5.1
#   Downloading ndg_httpsclient-0.5.1-py3-none-any.whl (34 kB)
# Collecting jmespath<1.0.0
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Collecting adal<=1.2.7,>=1.2.0
#   Downloading adal-1.2.7-py2.py3-none-any.whl (55 kB)
# Collecting backports.tempfile
#   Downloading backports.tempfile-1.0-py2.py3-none-any.whl (4.4 kB)
# Collecting msrestazure<=0.6.4,>=0.4.33
#   Downloading msrestazure-0.6.4-py2.py3-none-any.whl (40 kB)
# Collecting azure-mgmt-authorization<1.0.0,>=0.40.0
#   Downloading azure_mgmt_authorization-0.61.0-py2.py3-none-any.whl (94 kB)
# Collecting PyJWT<3.0.0
#   Downloading PyJWT-2.3.0-py3-none-any.whl (16 kB)
# Collecting cryptography!=1.9,!=2.0.*,!=2.1.*,!=2.2.*,<4.0.0
#   Downloading cryptography-3.4.8-cp36-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.2 MB)
# Collecting pyopenssl<21.0.0
#   Downloading pyOpenSSL-20.0.1-py2.py3-none-any.whl (54 kB)
# Requirement already satisfied, skipping upgrade: python-dateutil<3.0.0,>=2.7.3 in /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib/python3.6/site-packages (from azureml-core~=1.34.0->azureml-sdk~=1.34.0->-r /azureml-environment-setup/condaenv.4qq4esib.requirements.txt (line 1)) (2.8.1)
# Requirement already satisfied, skipping upgrade: pytz in /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib/python3.6/site-packages (from azureml-core~=1.34.0->azureml-sdk~=1.34.0->-r /azureml-environment-setup/condaenv.4qq4esib.requirements.txt (line 1)) (2020.1)
# Collecting docker<6.0.0
#   Downloading docker-5.0.3-py2.py3-none-any.whl (146 kB)
# Collecting jsonpickle<3.0.0
#   Downloading jsonpickle-2.0.0-py2.py3-none-any.whl (37 kB)
# Collecting azure-mgmt-keyvault<10.0.0,>=0.40.0
#   Downloading azure_mgmt_keyvault-9.3.0-py2.py3-none-any.whl (412 kB)
# Collecting ruamel.yaml<0.17.5,>=0.15.35
#   Downloading ruamel.yaml-0.17.4-py3-none-any.whl (101 kB)
# Collecting azure-mgmt-resource<15.0.0,>=1.2.1
#   Downloading azure_mgmt_resource-13.0.0-py2.py3-none-any.whl (1.3 MB)
# Collecting msrest<1.0.0,>=0.5.1
#   Downloading msrest-0.6.21-py2.py3-none-any.whl (85 kB)
# Collecting SecretStorage<4.0.0
#   Downloading SecretStorage-3.3.1-py3-none-any.whl (15 kB)
# Collecting azureml-telemetry~=1.34.0
#   Downloading azureml_telemetry-1.34.0-py3-none-any.whl (30 kB)
# Collecting azureml-train-restclients-hyperdrive~=1.34.0
#   Downloading azureml_train_restclients_hyperdrive-1.34.0-py3-none-any.whl (19 kB)
# Collecting azureml-dataprep<2.23.0a,>=2.22.0a
#   Downloading azureml_dataprep-2.22.2-py3-none-any.whl (39.4 MB)
# Collecting fusepy<4.0.0,>=3.0.1; extra == "fuse"
#   Downloading fusepy-3.0.1.tar.gz (11 kB)
# Collecting azureml-automl-core~=1.34.0
#   Downloading azureml_automl_core-1.34.1-py3-none-any.whl (217 kB)
# Collecting idna<4,>=2.5; python_version >= "3"
#   Downloading idna-3.3-py3-none-any.whl (61 kB)
# Collecting charset-normalizer~=2.0.0; python_version >= "3"
#   Downloading charset_normalizer-2.0.7-py3-none-any.whl (38 kB)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib/python3.6/site-packages (from requests<3.0.0,>=2.19.1->azureml-core~=1.34.0->azureml-sdk~=1.34.0->-r /azureml-environment-setup/condaenv.4qq4esib.requirements.txt (line 1)) (2020.6.20)
# Collecting azure-mgmt-core<2.0.0,>=1.2.0
#   Downloading azure_mgmt_core-1.3.0-py2.py3-none-any.whl (25 kB)
# Collecting pyasn1>=0.1.1
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# Collecting backports.weakref
#   Downloading backports.weakref-1.0.post1-py2.py3-none-any.whl (5.2 kB)
# Requirement already satisfied, skipping upgrade: six in /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib/python3.6/site-packages (from msrestazure<=0.6.4,>=0.4.33->azureml-core~=1.34.0->azureml-sdk~=1.34.0->-r /azureml-environment-setup/condaenv.4qq4esib.requirements.txt (line 1)) (1.15.0)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.0-cp36-cp36m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (405 kB)
# Collecting websocket-client>=0.32.0
#   Downloading websocket_client-1.2.1-py2.py3-none-any.whl (52 kB)
# Collecting importlib-metadata; python_version < "3.8"
#   Downloading importlib_metadata-4.8.2-py3-none-any.whl (17 kB)
# Collecting ruamel.yaml.clib>=0.1.2; platform_python_implementation == "CPython" and python_version < "3.10"
#   Downloading ruamel.yaml.clib-0.2.6-cp36-cp36m-manylinux1_x86_64.whl (552 kB)
# Collecting isodate>=0.6.0
#   Downloading isodate-0.6.0-py2.py3-none-any.whl (45 kB)
# Collecting requests-oauthlib>=0.5.0
#   Downloading requests_oauthlib-1.3.0-py2.py3-none-any.whl (23 kB)
# Collecting jeepney>=0.6
#   Downloading jeepney-0.7.1-py3-none-any.whl (54 kB)
# Collecting applicationinsights
#   Downloading applicationinsights-0.11.10-py2.py3-none-any.whl (55 kB)
# Collecting azureml-dataprep-native<39.0.0,>=38.0.0
#   Downloading azureml_dataprep_native-38.0.0-cp36-cp36m-manylinux1_x86_64.whl (1.3 MB)
# Collecting azure-identity<1.5.0,>=1.2.0
#   Downloading azure_identity-1.4.1-py2.py3-none-any.whl (86 kB)
# Collecting cloudpickle<2.0.0,>=1.1.0
#   Downloading cloudpickle-1.6.0-py3-none-any.whl (23 kB)
# Collecting dotnetcore2<3.0.0,>=2.1.14
#   Downloading dotnetcore2-2.1.21-py3-none-manylinux1_x86_64.whl (28.7 MB)
# Collecting azureml-dataprep-rslex~=1.20.0dev0
#   Downloading azureml_dataprep_rslex-1.20.2-cp36-cp36m-manylinux1_x86_64.whl (10.9 MB)
# Collecting azure-core<2.0.0,>=1.15.0
#   Downloading azure_core-1.20.1-py2.py3-none-any.whl (177 kB)
# Collecting pycparser
#   Downloading pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Collecting zipp>=0.5
#   Downloading zipp-3.6.0-py3-none-any.whl (5.3 kB)
# Collecting typing-extensions>=3.6.4; python_version < "3.8"
#   Downloading typing_extensions-4.0.0-py3-none-any.whl (22 kB)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.1.1-py2.py3-none-any.whl (146 kB)
# Collecting msal<2.0.0,>=1.3.0
#   Downloading msal-1.16.0-py2.py3-none-any.whl (78 kB)
# Collecting msal-extensions~=0.2.2
#   Downloading msal_extensions-0.2.2-py2.py3-none-any.whl (15 kB)
# Collecting distro>=1.2.0
#   Downloading distro-1.6.0-py2.py3-none-any.whl (19 kB)
# Collecting portalocker~=1.0; platform_system != "Windows"
#   Downloading portalocker-1.7.1-py2.py3-none-any.whl (10 kB)
# Building wheels for collected packages: fusepy
#   Building wheel for fusepy (setup.py): started
#   Building wheel for fusepy (setup.py): finished with status 'done'
#   Created wheel for fusepy: filename=fusepy-3.0.1-py3-none-any.whl size=10504 sha256=b902c2485802b8f4aab76371ce1c56bb949e48088de8af1524f8477c65bd82fd
#   Stored in directory: /root/.cache/pip/wheels/21/5c/83/1dd7e8a232d12227e5410120f4374b33adeb4037473105b079
# Successfully built fusepy
# Installing collected packages: urllib3, contextlib2, idna, charset-normalizer, requests, isodate, oauthlib, requests-oauthlib, msrest, pycparser, cffi, cryptography, PyJWT, adal, msrestazure, azure-common, azure-graphrbac, azure-core, azure-mgmt-core, azure-mgmt-containerregistry, pathspec, azure-mgmt-storage, pyasn1, pyopenssl, ndg-httpsclient, jmespath, backports.weakref, backports.tempfile, azure-mgmt-authorization, websocket-client, docker, zipp, typing-extensions, importlib-metadata, jsonpickle, azure-mgmt-keyvault, ruamel.yaml.clib, ruamel.yaml, azure-mgmt-resource, jeepney, SecretStorage, azureml-core, azureml-pipeline-core, azureml-dataprep-native, msal, portalocker, msal-extensions, azure-identity, cloudpickle, distro, dotnetcore2, azureml-dataprep-rslex, azureml-dataprep, pyarrow, fusepy, azureml-dataset-runtime, applicationinsights, azureml-telemetry, azureml-automl-core, azureml-train-automl-client, azureml-train-restclients-hyperdrive, azureml-train-core, azureml-pipeline-steps, azureml-pipeline, azureml-sdk
# Successfully installed PyJWT-2.3.0 SecretStorage-3.3.1 adal-1.2.7 applicationinsights-0.11.10 azure-common-1.1.27 azure-core-1.20.1 azure-graphrbac-0.61.1 azure-identity-1.4.1 azure-mgmt-authorization-0.61.0 azure-mgmt-containerregistry-8.2.0 azure-mgmt-core-1.3.0 azure-mgmt-keyvault-9.3.0 azure-mgmt-resource-13.0.0 azure-mgmt-storage-11.2.0 azureml-automl-core-1.34.1 azureml-core-1.34.0 azureml-dataprep-2.22.2 azureml-dataprep-native-38.0.0 azureml-dataprep-rslex-1.20.2 azureml-dataset-runtime-1.34.0 azureml-pipeline-1.34.0 azureml-pipeline-core-1.34.0 azureml-pipeline-steps-1.34.0 azureml-sdk-1.34.0 azureml-telemetry-1.34.0 azureml-train-automl-client-1.34.0 azureml-train-core-1.34.0 azureml-train-restclients-hyperdrive-1.34.0 backports.tempfile-1.0 backports.weakref-1.0.post1 cffi-1.15.0 charset-normalizer-2.0.7 cloudpickle-1.6.0 contextlib2-21.6.0 cryptography-3.4.8 distro-1.6.0 docker-5.0.3 dotnetcore2-2.1.21 fusepy-3.0.1 idna-3.3 importlib-metadata-4.8.2 isodate-0.6.0 jeepney-0.7.1 jmespath-0.10.0 jsonpickle-2.0.0 msal-1.16.0 msal-extensions-0.2.2 msrest-0.6.21 msrestazure-0.6.4 ndg-httpsclient-0.5.1 oauthlib-3.1.1 pathspec-0.9.0 portalocker-1.7.1 pyarrow-6.0.1 pyasn1-0.4.8 pycparser-2.21 pyopenssl-20.0.1 requests-2.26.0 requests-oauthlib-1.3.0 ruamel.yaml-0.17.4 ruamel.yaml.clib-0.2.6 typing-extensions-4.0.0 urllib3-1.26.6 websocket-client-1.2.1 zipp-3.6.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
#
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 4.10.3
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
# WARNING: /root/.conda/pkgs does not exist
# Removing intermediate container 23e53e764950
#  ---> 88ac008dfd6c
# Step 9/19 : ENV PATH /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/bin:$PATH
#  ---> Running in e680aedf9bcb
# Removing intermediate container e680aedf9bcb
#  ---> 77eedf069a15
# Step 10/19 : COPY azureml-environment-setup/send_conda_dependencies.py azureml-environment-setup/send_conda_dependencies.py
#  ---> ac5497227aaf
# Step 11/19 : RUN echo "Copying environment context"
#  ---> Running in dbeaf9cc6721
# Copying environment context
# Removing intermediate container dbeaf9cc6721
#  ---> 9340df95b875
# Step 12/19 : COPY azureml-environment-setup/environment_context.json azureml-environment-setup/environment_context.json
#  ---> 8bab6331f96e
# Step 13/19 : RUN python /azureml-environment-setup/send_conda_dependencies.py -p /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7
#  ---> Running in b1e67b19a0b0
# Report materialized dependencies for the environment
# Reading environment context
# Exporting conda environment
# Sending request with materialized conda environment details
# Successfully sent materialized environment details
# Removing intermediate container b1e67b19a0b0
#  ---> 4fb6eff85b61
# Step 14/19 : ENV AZUREML_CONDA_ENVIRONMENT_PATH /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7
#  ---> Running in 798b70ed4d94
# Removing intermediate container 798b70ed4d94
#  ---> 9436c33425d6
# Step 15/19 : ENV LD_LIBRARY_PATH /azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib:$LD_LIBRARY_PATH
#  ---> Running in a01f72fb3e12
# Removing intermediate container a01f72fb3e12
#  ---> 0d47a34874fd
# Step 16/19 : COPY azureml-environment-setup/spark_cache.py azureml-environment-setup/log4j.properties /azureml-environment-setup/
#  ---> 8631c4adeff0
# Step 17/19 : RUN if [ $SPARK_HOME ]; then /bin/bash -c '$SPARK_HOME/bin/spark-submit  /azureml-environment-setup/spark_cache.py'; fi
#  ---> Running in 195946483e3d
# Removing intermediate container 195946483e3d
#  ---> 9ea92bf26b07
# Step 18/19 : ENV AZUREML_ENVIRONMENT_IMAGE True
#  ---> Running in 9e9bbeb967fa
# Removing intermediate container 9e9bbeb967fa
#  ---> 82c293b86322
# Step 19/19 : CMD ["bash"]
#  ---> Running in ecadc9c12fa5
# Removing intermediate container ecadc9c12fa5
#  ---> f6616a7f06c0
# Successfully built f6616a7f06c0
# Successfully tagged e6fafec881fb4906968577c5282597a0.azurecr.io/azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b:latest
# Successfully tagged e6fafec881fb4906968577c5282597a0.azurecr.io/azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b:1
# 2021/11/24 05:29:42 Successfully executed container: acb_step_0
# 2021/11/24 05:29:42 Executing step ID: acb_step_1. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/24 05:29:42 Pushing image: e6fafec881fb4906968577c5282597a0.azurecr.io/azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b:1, attempt 1
# The push refers to repository [e6fafec881fb4906968577c5282597a0.azurecr.io/azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b]
# 03437ef74bd6: Preparing
# 27edf6bddc9e: Preparing
# f3f71fd0ad91: Preparing
# 24f17d806885: Preparing
# a1b4d1a419e7: Preparing
# 95ebfaeaa45b: Preparing
# c712b2cf727d: Preparing
# 6fb7efe68b1f: Preparing
# 4e13b28220d7: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# 95ebfaeaa45b: Waiting
# c712b2cf727d: Waiting
# 6fb7efe68b1f: Waiting
# 4e13b28220d7: Waiting
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# 94c0f7816c07: Waiting
# accea658c5be: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# 03437ef74bd6: Pushed
# 27edf6bddc9e: Pushed
# f3f71fd0ad91: Pushed
# 24f17d806885: Pushed
# 95ebfaeaa45b: Pushed
# c712b2cf727d: Pushed
# 6fb7efe68b1f: Pushed
# 4e13b28220d7: Pushed
# 93c9ec44fed0: Pushed
# 9398792c8299: Pushed
# e0ae5bb40eae: Pushed
# 94c0f7816c07: Pushed
# 5e9c7e64af11: Pushed
# accea658c5be: Pushed
# 21639b09744f: Pushed
# 20e11b7f408c: Pushed
#
# c96f19f3c075: Pushed
# a1b4d1a419e7: Pushed
# 1: digest: sha256:13dda8102c03a0cd0d7229a6c0103bba8e8a289eeedbdf0d09fcf74d73e60f52 size: 4099
# 2021/11/24 05:31:08 Successfully pushed image: e6fafec881fb4906968577c5282597a0.azurecr.io/azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b:1
# 2021/11/24 05:31:08 Executing step ID: acb_step_2. Timeout(sec): 5400, Working directory: '', Network: 'acb_default_network'
# 2021/11/24 05:31:08 Pushing image: e6fafec881fb4906968577c5282597a0.azurecr.io/azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b:latest, attempt 1
# The push refers to repository [e6fafec881fb4906968577c5282597a0.azurecr.io/azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b]
# 03437ef74bd6: Preparing
# 27edf6bddc9e: Preparing
# f3f71fd0ad91: Preparing
# 24f17d806885: Preparing
# a1b4d1a419e7: Preparing
# 95ebfaeaa45b: Preparing
# c712b2cf727d: Preparing
# 6fb7efe68b1f: Preparing
# 4e13b28220d7: Preparing
# 9398792c8299: Preparing
# 93c9ec44fed0: Preparing
# e0ae5bb40eae: Preparing
# 5e9c7e64af11: Preparing
# 20e11b7f408c: Preparing
# 94c0f7816c07: Preparing
# accea658c5be: Preparing
# c96f19f3c075: Preparing
# 21639b09744f: Preparing
# 95ebfaeaa45b: Waiting
# c712b2cf727d: Waiting
# 6fb7efe68b1f: Waiting
# 4e13b28220d7: Waiting
# 9398792c8299: Waiting
# 93c9ec44fed0: Waiting
# e0ae5bb40eae: Waiting
# 5e9c7e64af11: Waiting
# 20e11b7f408c: Waiting
# 94c0f7816c07: Waiting
# accea658c5be: Waiting
# c96f19f3c075: Waiting
# 21639b09744f: Waiting
# 27edf6bddc9e: Layer already exists
# 03437ef74bd6: Layer already exists
# a1b4d1a419e7: Layer already exists
# f3f71fd0ad91: Layer already exists
# 24f17d806885: Layer already exists
# 95ebfaeaa45b: Layer already exists
# 6fb7efe68b1f: Layer already exists
# 4e13b28220d7: Layer already exists
# 9398792c8299: Layer already exists
# e0ae5bb40eae: Layer already exists
# 93c9ec44fed0: Layer already exists
# 5e9c7e64af11: Layer already exists
# 20e11b7f408c: Layer already exists
# 94c0f7816c07: Layer already exists
# c96f19f3c075: Layer already exists
# 21639b09744f: Layer already exists
# accea658c5be: Layer already exists
# c712b2cf727d: Layer already exists
# latest: digest: sha256:13dda8102c03a0cd0d7229a6c0103bba8e8a289eeedbdf0d09fcf74d73e60f52 size: 4099
# 2021/11/24 05:31:10 Successfully pushed image: e6fafec881fb4906968577c5282597a0.azurecr.io/azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b:latest
# 2021/11/24 05:31:10 Step ID: acb_step_0 marked as successful (elapsed time in seconds: 194.363249)
# 2021/11/24 05:31:10 Populating digests for step ID: acb_step_0...
# 2021/11/24 05:31:11 Successfully populated digests for step ID: acb_step_0
# 2021/11/24 05:31:11 Step ID: acb_step_1 marked as successful (elapsed time in seconds: 85.901325)
# 2021/11/24 05:31:11 Step ID: acb_step_2 marked as successful (elapsed time in seconds: 2.152967)
# 2021/11/24 05:31:11 The following dependencies were found:
# 2021/11/24 05:31:11
# - image:
#     registry: e6fafec881fb4906968577c5282597a0.azurecr.io
#     repository: azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b
#     tag: latest
#     digest: sha256:13dda8102c03a0cd0d7229a6c0103bba8e8a289eeedbdf0d09fcf74d73e60f52
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
# - image:
#     registry: e6fafec881fb4906968577c5282597a0.azurecr.io
#     repository: azureml/azureml_b5b8149428fb534ae0132ff2eff07b1b
#     tag: "1"
#     digest: sha256:13dda8102c03a0cd0d7229a6c0103bba8e8a289eeedbdf0d09fcf74d73e60f52
#   runtime-dependency:
#     registry: mcr.microsoft.com
#     repository: azureml/openmpi3.1.2-ubuntu18.04
#     tag: 20210806.v1
#     digest: sha256:bb94557d668c1cebffb04d0a77aa461776f697753fb9ddf2784f8e65f47ff47c
#   git: {}
#
#
# Run ID: can was successful after 4m47s
#
# Streaming azureml-logs/55_azureml-execution-tvmps_abf798226dd9d1907898c92bc4c5ca89-master-0_d.txt
# =================================================================================================
#
# Streaming azureml-logs/75_job_post-tvmps_abf798226dd9d1907898c92bc4c5ca89-master-0_d.txt
# ========================================================================================
# [2021-11-24T05:36:34.627029] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (pyarrow 6.0.1 (/azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib/python3.6/site-packages), Requirement.parse('pyarrow<4.0.0,>=0.17.0'), {'azureml-dataset-runtime'}).
# Cannot provide tracer without any exporter configured.
# [2021-11-24T05:36:35.689126] Starting job release
# [2021-11-24T05:36:35.689522] Logging experiment finalizing status in history service.
# [2021-11-24T05:36:35.689691] job release stage : upload_datastore starting...
# Starting the daemon thread to refresh tokens in background for process with pid = 1130
# [2021-11-24T05:36:35.690070] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-24T05:36:35.690331] job release stage : execute_job_release starting...
# [2021-11-24T05:36:35.690507] job release stage : copy_batchai_cached_logs starting...
# [2021-11-24T05:36:35.690548] job release stage : copy_batchai_cached_logs completed...
# [2021-11-24T05:36:35.699302] Entering context manager injector.
# Cannot provide tracer without any exporter configured.
# [2021-11-24T05:36:35.702924] job release stage : upload_datastore completed...
# [2021-11-24T05:36:36.948165] job release stage : send_run_telemetry starting...
# [2021-11-24T05:36:36.953515] Job release stage : send_run_telemetry WARNING : Environment variable AZ_BATCHAI_RUN_STATUS is not set
# [2021-11-24T05:36:36.953540] job release stage : send_run_telemetry completed...
# [2021-11-24T05:36:37.036954] job release stage : execute_job_release completed...
# [2021-11-24T05:36:37.037043] Job release is complete
#
# StepRun(Cleanse Green Taxi Data) Execution Summary
# ===================================================
# StepRun( Cleanse Green Taxi Data ) Status: Finished
# {'runId': '630ff845-c767-40cc-84ce-0487e0be32ee', 'target': 'arc-compute3', 'status': 'Completed', 'startTimeUtc': '2021-11-24T05:36:46.563419Z', 'endTimeUtc': '2021-11-24T05:38:47.411155Z', 'services': {}, 'properties': {'ContentSnapshotId': '70a20c40-518f-46d3-a25c-345437795606', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '745dcc1e-612d-4406-b63a-87dc5cd8de02', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': 'fe604d49', 'azureml.pipelinerunid': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'azureml.pipeline': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'kubernetes', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'JobType': 'RegularJob', 'GpuCount': '0', 'Cluster': 'my-workload-cluster'}, 'inputDatasets': [{'dataset': {'id': 'c45e2dd5-007a-4254-8881-7129d917a398'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': '65c2f4b5-bf37-488a-a9bd-d578fbea0828'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'cleansed_green_data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/630ff845-c767-40cc-84ce-0487e0be32ee/cleansed_green_data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "65c2f4b5-bf37-488a-a9bd-d578fbea0828",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='amlarc-sample-test-ws-eastus', subscription_id='86204643-5a96-427b-b6bb-b35b2bd6e6ce', resource_group='AKS-HCI2')"
#   }
# }}], 'runDefinition': {'script': 'cleanse.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--data-path', 'DatasetConsumptionConfig:raw_data', '--useful_columns', "['cost'; 'distance'; 'dropoff_datetime'; 'dropoff_latitude'; 'dropoff_longitude'; 'passengers'; 'pickup_datetime'; 'pickup_latitude'; 'pickup_longitude'; 'store_forward'; 'vendor']", '--columns_key', "['vendorID'; 'lpepPickupDatetime'; 'lpepDropoffDatetime'; 'storeAndFwdFlag'; 'pickupLongitude'; 'pickupLatitude'; 'dropoffLongitude'; 'dropoffLatitude'; 'passengerCount'; 'fareAmount'; 'tripDistance']", '--columns_value', "['vendor'; 'pickup_datetime'; 'dropoff_datetime'; 'store_forward'; 'pickup_longitude'; 'pickup_latitude'; 'dropoff_longitude'; 'dropoff_latitude'; 'passengers'; 'cost'; 'distance']", '--output_cleanse', 'DatasetOutputConfig:cleansed_green_data'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'arc-compute3', 'dataReferences': {}, 'data': {'raw_data': {'dataLocation': {'dataset': {'id': 'c45e2dd5-007a-4254-8881-7129d917a398', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'raw_data', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'cleansed_green_data': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Upload', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment NYCTaxi_Tutorial_Pipelines Environment', 'version': 'Autosave_2021-11-24T05:26:21Z_3756a9e7', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.34.0', 'pyarrow']}, 'pandas', 'scikit-learn'], 'name': 'azureml_c20ec418ebf1ca0df927289ca06943e7'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docke ...
#
#
#
#
# StepRunId: 3c677cf6-e83c-46ce-8f3c-6c133f771cb7
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/3c677cf6-e83c-46ce-8f3c-6c133f771cb7?wsid=/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourcegroups/AKS-HCI2/workspaces/amlarc-sample-test-ws-eastus&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( Cleanse Yellow Taxi Data ) Status: Running
#
# Streaming azureml-logs/75_job_post-tvmps_3c81edefcf0ae7a19d7ba1b161668154-master-0_d.txt
# ========================================================================================
# [2021-11-24T05:36:34.749951] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (pyarrow 6.0.1 (/azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib/python3.6/site-packages), Requirement.parse('pyarrow<4.0.0,>=0.17.0'), {'azureml-dataset-runtime'}).
# Cannot provide tracer without any exporter configured.
# [2021-11-24T05:36:35.839609] Starting job release
# [2021-11-24T05:36:35.839981] Logging experiment finalizing status in history service.
# [2021-11-24T05:36:35.840155] job release stage : upload_datastore starting...
# [2021-11-24T05:36:35.840349] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-24T05:36:35.840388] job release stage : execute_job_release starting...
# [2021-11-24T05:36:35.840606] job release stage : copy_batchai_cached_logs starting...
# [2021-11-24T05:36:35.840648] job release stage : copy_batchai_cached_logs completed...
# Starting the daemon thread to refresh tokens in background for process with pid = 1116
# [2021-11-24T05:36:35.843492] Entering context manager injector.
# Cannot provide tracer without any exporter configured.
# [2021-11-24T05:36:35.853185] job release stage : upload_datastore completed...
# [2021-11-24T05:36:37.060324] job release stage : send_run_telemetry starting...
# [2021-11-24T05:36:37.065584] Job release stage : send_run_telemetry WARNING : Environment variable AZ_BATCHAI_RUN_STATUS is not set
# [2021-11-24T05:36:37.065611] job release stage : send_run_telemetry completed...
# [2021-11-24T05:36:37.191787] job release stage : execute_job_release completed...
# [2021-11-24T05:36:37.191885] Job release is complete
#
# StepRun(Cleanse Yellow Taxi Data) Execution Summary
# ====================================================
# StepRun( Cleanse Yellow Taxi Data ) Status: Finished
# {'runId': '3c677cf6-e83c-46ce-8f3c-6c133f771cb7', 'target': 'arc-compute3', 'status': 'Completed', 'startTimeUtc': '2021-11-24T05:36:16.045514Z', 'endTimeUtc': '2021-11-24T05:40:17.15384Z', 'services': {}, 'properties': {'ContentSnapshotId': '70a20c40-518f-46d3-a25c-345437795606', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '9cb5e7b4-da00-425e-9bd3-9e7522a5c5e4', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '7fc00336', 'azureml.pipelinerunid': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'azureml.pipeline': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'kubernetes', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'JobType': 'RegularJob', 'GpuCount': '0', 'Cluster': 'my-workload-cluster'}, 'inputDatasets': [{'dataset': {'id': 'de1355e1-0ca6-44b4-a685-f9ab9a1876f8'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'raw_data', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': 'df175344-97c5-45ff-806e-3d536334425e'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'cleansed_yellow_data'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/3c677cf6-e83c-46ce-8f3c-6c133f771cb7/cleansed_yellow_data/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "df175344-97c5-45ff-806e-3d536334425e",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='amlarc-sample-test-ws-eastus', subscription_id='86204643-5a96-427b-b6bb-b35b2bd6e6ce', resource_group='AKS-HCI2')"
#   }
# ...
# [2021-11-24T06:02:54.842648] job release stage : copy_batchai_cached_logs starting...
# [2021-11-24T06:02:54.842861] job release stage : copy_batchai_cached_logs completed...
# [2021-11-24T06:02:54.850712] Entering context manager injector.
# Cannot provide tracer without any exporter configured.
# [2021-11-24T06:02:54.854125] job release stage : upload_datastore completed...
# [2021-11-24T06:02:56.129862] job release stage : send_run_telemetry starting...
# [2021-11-24T06:02:56.135072] Job release stage : send_run_telemetry WARNING : Environment variable AZ_BATCHAI_RUN_STATUS is not set
# [2021-11-24T06:02:56.135095] job release stage : send_run_telemetry completed...
# [2021-11-24T06:02:56.208537] job release stage : execute_job_release completed...
# [2021-11-24T06:02:56.208626] Job release is complete
#
# StepRun(Train Test Data Split) Execution Summary
# =================================================
# StepRun( Train Test Data Split ) Status: Finished
# {'runId': 'fcc3e92d-b9ad-4432-89b7-171686cfd0fa', 'target': 'arc-compute3', 'status': 'Completed', 'startTimeUtc': '2021-11-24T06:03:28.923403Z', 'endTimeUtc': '2021-11-24T06:05:29.483307Z', 'services': {}, 'properties': {'ContentSnapshotId': '75d0e73c-46a0-4110-8a1f-3d19132990fb', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '982a0907-98f9-498c-a0db-042e9bbd6514', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '8bc2e8d4', 'azureml.pipelinerunid': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'azureml.pipeline': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'kubernetes', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'JobType': 'RegularJob', 'GpuCount': '0', 'Cluster': 'my-workload-cluster'}, 'inputDatasets': [{'dataset': {'id': 'b0694fa8-ef00-486a-9fd7-6c4e66105409'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_82c9e173', 'mechanism': 'Mount'}}], 'outputDatasets': [{'identifier': {'savedId': '1ff68033-b3a0-495b-a8e0-f2ef8106234b'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'output_split_train'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/fcc3e92d-b9ad-4432-89b7-171686cfd0fa/output_split_train/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "1ff68033-b3a0-495b-a8e0-f2ef8106234b",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='amlarc-sample-test-ws-eastus', subscription_id='86204643-5a96-427b-b6bb-b35b2bd6e6ce', resource_group='AKS-HCI2')"
#   }
# }}, {'identifier': {'savedId': '83a8b9db-9e4e-41bb-a197-6cd41604ced8'}, 'outputType': 'RunOutput', 'outputDetails': {'outputName': 'output_split_test'}, 'dataset': {
#   "source": [
#     "('workspaceblobstore', 'dataset/fcc3e92d-b9ad-4432-89b7-171686cfd0fa/output_split_test/')"
#   ],
#   "definition": [
#     "GetDatastoreFiles"
#   ],
#   "registration": {
#     "id": "83a8b9db-9e4e-41bb-a197-6cd41604ced8",
#     "name": null,
#     "version": null,
#     "workspace": "Workspace.create(name='amlarc-sample-test-ws-eastus', subscription_id='86204643-5a96-427b-b6bb-b35b2bd6e6ce', resource_group='AKS-HCI2')"
#   }
# }}], 'runDefinition': {'script': 'train_test_split.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--data-path', 'DatasetConsumptionConfig:input_82c9e173', '--output_split_train', 'DatasetOutputConfig:output_split_train', '--output_split_test', 'DatasetOutputConfig:output_split_test'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'arc-compute3', 'dataReferences': {}, 'data': {'input_82c9e173': {'dataLocation': {'dataset': {'id': 'b0694fa8-ef00-486a-9fd7-6c4e66105409', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_82c9e173', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {'output_split_train': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Upload', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}, 'output_split_test': {'outputLocation': {'dataset': None, 'dataPath': {'datastoreName': 'workspaceblobstore', 'relativePath': None}, 'uri': None}, 'mechanism': 'Upload', 'additionalOptions': {'pathOnCompute': None, 'registrationOptions': {'name': None, 'description': None, 'tags': None, 'datasetRegistrationOptions': {'additionalTransformation': None}}, 'uploadOptions': {'overwrite': False, 'sourceGlobs': {'globPatterns': None}}, 'mountOptions': None}, 'environmentVariableName': None}}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment NYCTaxi_Tutorial_Pipelines Environment', 'version': 'Autosave_2021-11-24T05:26:21Z_3756a9e7', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.34.0', 'pyarrow']}, 'pandas', 'scikit-learn'], 'name': 'azureml_c20ec418ebf1ca0df927289ca06943e7'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Medium', 'slaTier': 'Standard', 'userAlias': None}, 'kubernetesCompute': {'instanceType': None}, 'tensorflow': {'workerCount': 1, 'parameterServerCount': 1}, 'mpi': {'processCountPerNode': 1}, 'pyTorch': {'communicationBackend': 'nccl', 'processCount': None}, 'hdi': {'yarnDeployMode': 'Cluster'}, 'containerInstance': {'region': None, 'cpuCores': 2.0, 'memoryGb': 3.5}, 'exposedPorts': None, 'docker': {'useDocker': False, 'sharedVolumes': Tru ...
#
#
#
#
# StepRunId: 65a69467-fcc4-46ee-814c-6a4646eaf2f5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/65a69467-fcc4-46ee-814c-6a4646eaf2f5?wsid=/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourcegroups/AKS-HCI2/workspaces/amlarc-sample-test-ws-eastus&tid=72f988bf-86f1-41af-91ab-2d7cd011db47
# StepRun( train_step ) Status: Running
#
# Streaming azureml-logs/55_azureml-execution-tvmps_cb75b55aea055a85b0554df3dc94e85f-master-0_d.txt
# =================================================================================================
#
# Streaming azureml-logs/65_job_prep-tvmps_cb75b55aea055a85b0554df3dc94e85f-master-0_d.txt
# ========================================================================================
#
# Streaming azureml-logs/75_job_post-tvmps_cb75b55aea055a85b0554df3dc94e85f-master-0_d.txt
# ========================================================================================
# [2021-11-24T06:07:13.369899] Entering job release
# Failure while loading azureml_run_type_providers. Failed to load entrypoint automl = azureml.train.automl.run:AutoMLRun._from_run_dto with exception (pyarrow 6.0.1 (/azureml-envs/azureml_c20ec418ebf1ca0df927289ca06943e7/lib/python3.6/site-packages), Requirement.parse('pyarrow<4.0.0,>=0.17.0'), {'azureml-dataset-runtime'}).
# Cannot provide tracer without any exporter configured.
# [2021-11-24T06:07:14.417985] Starting job release
# [2021-11-24T06:07:14.418397] Logging experiment finalizing status in history service.
# Starting the daemon thread to refresh tokens in background for process with pid = 1169
# [2021-11-24T06:07:14.418669] job release stage : upload_datastore starting...
# [2021-11-24T06:07:14.418933] job release stage : start importing azureml.history._tracking in run_history_release.
# [2021-11-24T06:07:14.419290] job release stage : execute_job_release starting...
# [2021-11-24T06:07:14.428897] Entering context manager injector.
# [2021-11-24T06:07:14.429462] job release stage : copy_batchai_cached_logs starting...
# [2021-11-24T06:07:14.429509] job release stage : copy_batchai_cached_logs completed...
# Cannot provide tracer without any exporter configured.
# [2021-11-24T06:07:14.431737] job release stage : upload_datastore completed...
# [2021-11-24T06:07:15.730840] job release stage : send_run_telemetry starting...
# [2021-11-24T06:07:15.735952] Job release stage : send_run_telemetry WARNING : Environment variable AZ_BATCHAI_RUN_STATUS is not set
# [2021-11-24T06:07:15.735976] job release stage : send_run_telemetry completed...
# [2021-11-24T06:07:15.790665] job release stage : execute_job_release completed...
# [2021-11-24T06:07:15.790736] Job release is complete
#
# StepRun(train_step) Execution Summary
# ======================================
# StepRun( train_step ) Status: Finished
# {'runId': '65a69467-fcc4-46ee-814c-6a4646eaf2f5', 'target': 'arc-compute3', 'status': 'Completed', 'startTimeUtc': '2021-11-24T06:08:02.675127Z', 'endTimeUtc': '2021-11-24T06:10:03.240192Z', 'services': {}, 'properties': {'ContentSnapshotId': '75d0e73c-46a0-4110-8a1f-3d19132990fb', 'StepType': 'PythonScriptStep', 'azureml.moduleid': '6a5373cd-fb70-44f9-9ea5-c10cdc1b12da', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '732fe391', 'azureml.pipelinerunid': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'azureml.pipeline': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'azureml.pipelineComponent': 'masterescloud', '_azureml.ComputeTargetType': 'kubernetes', 'ProcessInfoFile': 'azureml-logs/process_info.json', 'ProcessStatusFile': 'azureml-logs/process_status.json', 'JobType': 'RegularJob', 'GpuCount': '0', 'Cluster': 'my-workload-cluster'}, 'inputDatasets': [{'dataset': {'id': '1ff68033-b3a0-495b-a8e0-f2ef8106234b'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_25b533d4', 'mechanism': 'Mount'}}, {'dataset': {'id': '83a8b9db-9e4e-41bb-a197-6cd41604ced8'}, 'consumptionDetails': {'type': 'RunInput', 'inputName': 'input_d55ddf16', 'mechanism': 'Mount'}}], 'outputDatasets': [], 'runDefinition': {'script': 'train_step.py', 'command': '', 'useAbsolutePath': False, 'arguments': ['--train_data_path', 'DatasetConsumptionConfig:input_25b533d4', '--test_data_path', 'DatasetConsumptionConfig:input_d55ddf16'], 'sourceDirectoryDataStore': None, 'framework': 'Python', 'communicator': 'None', 'target': 'arc-compute3', 'dataReferences': {}, 'data': {'input_25b533d4': {'dataLocation': {'dataset': {'id': '1ff68033-b3a0-495b-a8e0-f2ef8106234b', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_25b533d4', 'pathOnCompute': None, 'overwrite': False, 'options': None}, 'input_d55ddf16': {'dataLocation': {'dataset': {'id': '83a8b9db-9e4e-41bb-a197-6cd41604ced8', 'name': None, 'version': None}, 'dataPath': None, 'uri': None}, 'mechanism': 'Mount', 'environmentVariableName': 'input_d55ddf16', 'pathOnCompute': None, 'overwrite': False, 'options': None}}, 'outputData': {}, 'datacaches': [], 'jobName': None, 'maxRunDurationSeconds': None, 'nodeCount': 1, 'instanceTypes': [], 'priority': None, 'credentialPassthrough': False, 'identity': None, 'environment': {'name': 'Experiment NYCTaxi_Tutorial_Pipelines Environment', 'version': 'Autosave_2021-11-24T05:26:21Z_3756a9e7', 'python': {'interpreterPath': 'python', 'userManagedDependencies': False, 'condaDependencies': {'channels': ['anaconda', 'conda-forge'], 'dependencies': ['python=3.6.2', {'pip': ['azureml-sdk~=1.34.0', 'pyarrow']}, 'pandas', 'scikit-learn'], 'name': 'azureml_c20ec418ebf1ca0df927289ca06943e7'}, 'baseCondaEnvironment': None}, 'environmentVariables': {'EXAMPLE_ENV_VAR': 'EXAMPLE_VALUE'}, 'docker': {'baseImage': 'mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210806.v1', 'platform': {'os': 'Linux', 'architecture': 'amd64'}, 'baseDockerfile': None, 'baseImageRegistry': {'address': None, 'username': None, 'password': None}, 'enabled': True, 'arguments': []}, 'spark': {'repositories': [], 'packages': [], 'precachePackages': True}, 'inferencingStackVersion': None}, 'history': {'outputCollection': True, 'directoriesToWatch': ['logs'], 'enableMLflowTracking': True, 'snapshotProject': True}, 'spark': {'configuration': {'spark.app.name': 'Azure ML Experiment', 'spark.yarn.maxAppAttempts': '1'}}, 'parallelTask': {'maxRetriesPerWorker': 0, 'workerCountPerNode': 1, 'terminalExitCodes': None, 'configuration': {}}, 'amlCompute': {'name': None, 'vmSize': None, 'retainCluster': False, 'clusterMaxNodeCount': 1}, 'aiSuperComputer': {'instanceType': 'D2', 'imageVersion': 'pytorch-1.7.0', 'location': None, 'aiSuperComputerStorageData': None, 'interactive': False, 'scalePolicy': None, 'virtualClusterArmId': None, 'tensorboardLogDirectory': None, 'sshPublicKey': None, 'sshPublicKeys': None, 'enableAzmlInt': True, 'priority': 'Mediu ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ac2b6821-e275-4fe6-9649-7a74c96c9e4f', 'status': 'Completed', 'startTimeUtc': '2021-11-24T05:26:17.375363Z', 'endTimeUtc': '2021-11-24T06:10:04.956929Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://amlarcsamplete7068317793.blob.core.windows.net/azureml/ExperimentRun/dcid.ac2b6821-e275-4fe6-9649-7a74c96c9e4f/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=cbDG%2FDk7YO6F3oA5YFy6IdN6dkEERVLNeb%2Fv2ownZXc%3D&skoid=46817ba8-5583-4d9d-a507-647580e5f28a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-24T05%3A16%3A18Z&ske=2021-11-25T13%3A26%3A18Z&sks=b&skv=2019-07-07&st=2021-11-24T06%3A00%3A12Z&se=2021-11-24T14%3A10%3A12Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://amlarcsamplete7068317793.blob.core.windows.net/azureml/ExperimentRun/dcid.ac2b6821-e275-4fe6-9649-7a74c96c9e4f/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=lIzTQrRtmLE9NiwQUfqb679dxFXA1IH3Ly9U2lIwr64%3D&skoid=46817ba8-5583-4d9d-a507-647580e5f28a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-24T05%3A16%3A18Z&ske=2021-11-25T13%3A26%3A18Z&sks=b&skv=2019-07-07&st=2021-11-24T06%3A00%3A12Z&se=2021-11-24T14%3A10%3A12Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://amlarcsamplete7068317793.blob.core.windows.net/azureml/ExperimentRun/dcid.ac2b6821-e275-4fe6-9649-7a74c96c9e4f/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=0YcwDFNAVjZafDS3PeDl0FNAy%2BSZshSvt7GoJ7WoEjE%3D&skoid=46817ba8-5583-4d9d-a507-647580e5f28a&sktid=72f988bf-86f1-41af-91ab-2d7cd011db47&skt=2021-11-24T05%3A16%3A18Z&ske=2021-11-25T13%3A26%3A18Z&sks=b&skv=2019-07-07&st=2021-11-24T06%3A00%3A12Z&se=2021-11-24T14%3A10%3A12Z&sp=r'}, 'submittedBy': 'Jiawei Du'}
# 'Finished'

# %% [markdown]
# ### Register the model
#
# Register the trained model.

# %%
train_step_run = pipeline_run.find_step_run(train_step.name)[0]

registered_model_name='taxi_model'
train_step_run.register_model(model_name=registered_model_name, model_path='outputs/taxi.pkl')
# Out:
# Model(workspace=Workspace.create(name='amlarc-sample-test-ws-eastus', subscription_id='86204643-5a96-427b-b6bb-b35b2bd6e6ce', resource_group='AKS-HCI2'), name=taxi_model, id=taxi_model:1, version=1, tags={}, properties={})

# %% [markdown]
# ### Get the model

# %%
from azureml.core.model import Model

model_name = registered_model_name
model = Model(ws, model_name)
model_id = f"azureml:{model.name}:{model.version}"
print(f"Get {model.name}, latest version {model.version}, id in deployment.yml: {model_id}")
# Out:
# Get taxi_model, latest version 1, id in endpoint.yml: azureml:taxi_model:1

# %% [markdown]
# The machine learning model named "taxi_model" should be registered in your AML workspace.

# %% [markdown]
# ## Test Registered Model
#
# To test the trained model, you can use AKS-HCI cluster for serving the model using AML deployment.

# %% [markdown]
# ### Deploy the model

# %%
# endpoint = '<tax-model endpoint name>'
endpoint = 'tax-model-jiadu'

import os
from pathlib import Path
prefix = Path(os.getcwd())
endpoint_file = str(prefix.joinpath("endpoint.yml"))
deployment_file = str(prefix.joinpath("deployment.yml"))
print(f"Using Endpoint file: {endpoint_file}, Deployment file: {deployment_file} please replace <modelId> (e.g. azureml:taxi_model:1), <instanceTypeName> (e.g. defaultInstanceType) and <computeTargetName> (e.g. azureml:amlarc-compute) according above output")
# Out:
# Using Endpoint file: e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\endpoint.yml, Deployment file: e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\deployment.yml please replace <modelId> (e.g. azureml:taxi_model:1), <instanceTypeName> (e.g. defaultInstanceType) and <computeTargetName> (e.g. azureml:amlarc-compute) according above output

# %% [markdown]
# Need to **replace the properties in deployment.yml**, including,
# * `<modelId>`: example value: azureml:taxi_model:1
# * `<instanceTypeName>`: example value: defaultInstanceType
#
# Need to **replace the properties in endpoint.yml**, including,
# * `<computeTargetName>`: example value: azureml:amlarc-compute

# %%
import helpers
from azureml.core.workspace import Workspace

ws = Workspace.from_config()
print('Workspace name: ' + ws.name, 
      'Azure region: ' + ws.location, 
      'Subscription id: ' + ws.subscription_id, 
      'Resource group: ' + ws.resource_group, sep='\n')
# Out:
# Workspace name: amlarc-sample-test-ws-eastus
# Azure region: eastus
# Subscription id: 86204643-5a96-427b-b6bb-b35b2bd6e6ce
# Resource group: AKS-HCI2

# %%
helpers.run(f"az ml online-endpoint create -n {endpoint} -f {endpoint_file} -w {ws.name} -g {ws.resource_group}")
# Out:
# START: az ml online-endpoint create -n tax-model-jiadu -f e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\endpoint.yml -w amlarc-sample-test-ws-eastus -g AKS-HCI2 @ 2021-11-24 15:11:26 (2021-11-24 07:11:26 UTC)
#        using: C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\wbin\az.CMD (Windows 10 on AMD64)
#        cwd: e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline
# {
#   "allow_public_access": true,
#   "auth_mode": "aml_token",
#   "compute": "azureml:/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourceGroups/AKS-HCI2/providers/Microsoft.MachineLearningServices/workspaces/amlarc-sample-test-ws-eastus/computes/arc-compute3",
#   "id": "/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourceGroups/AKS-HCI2/providers/Microsoft.MachineLearningServices/workspaces/amlarc-sample-test-ws-eastus/onlineEndpoints/tax-model-jiadu",
#   "identity": {
#     "principal_id": "d5770823-9c62-4ec5-a42c-422357a7c18e",
#     "tenant_id": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "type": "system_assigned"
#   },
#   "location": "eastus",
#   "name": "tax-model-jiadu",
#   "properties": {
#     "AzureAsyncOperationUri": "https://management.azure.com/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/providers/Microsoft.MachineLearningServices/locations/eastus/mfeOperationsStatus/oe:e6fafec8-81fb-4906-9685-77c5282597a0:c997d36f-720f-4f50-a45a-c51c84aae93e?api-version=2021-10-01",
#     "azureml.onlineendpointid": "/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourcegroups/aks-hci2/providers/microsoft.machinelearningservices/workspaces/amlarc-sample-test-ws-eastus/onlineendpoints/tax-model-jiadu"
#   },
#   "provisioning_state": "Succeeded",
#   "resourceGroup": "AKS-HCI2",
#   "scoring_uri": "http://10.156.95.33/api/v1/endpoint/tax-model-jiadu/score",
#   "swagger_uri": "http://10.156.95.33/api/v1/endpoint/tax-model-jiadu/swagger.json",
#   "tags": {},
#   "traffic": {}
# }
# STDERR: WARNING: Command group 'ml online-endpoint' is in preview and under development. Reference and support levels: https://aka.ms/CLI_refstatus
# STDERR: Creating or updating online_endpoints

# %%
helpers.run(f"az ml online-endpoint show -n {endpoint} -w {ws.name} -g {ws.resource_group}")
# Out:
# START: az ml online-endpoint show -n tax-model-jiadu -w amlarc-sample-test-ws-eastus -g AKS-HCI2 @ 2021-11-24 15:12:17 (2021-11-24 07:12:17 UTC)
#        using: C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\wbin\az.CMD (Windows 10 on AMD64)
#        cwd: e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline
# {
#   "allow_public_access": true,
#   "auth_mode": "aml_token",
#   "compute": "azureml:/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourceGroups/AKS-HCI2/providers/Microsoft.MachineLearningServices/workspaces/amlarc-sample-test-ws-eastus/computes/arc-compute3",
#   "id": "/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourceGroups/AKS-HCI2/providers/Microsoft.MachineLearningServices/workspaces/amlarc-sample-test-ws-eastus/onlineEndpoints/tax-model-jiadu",
#   "identity": {
#     "principal_id": "d5770823-9c62-4ec5-a42c-422357a7c18e",
#     "tenant_id": "72f988bf-86f1-41af-91ab-2d7cd011db47",
#     "type": "system_assigned"
#   },
#   "location": "eastus",
#   "name": "tax-model-jiadu",
#   "properties": {
#     "AzureAsyncOperationUri": "https://management.azure.com/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/providers/Microsoft.MachineLearningServices/locations/eastus/mfeOperationsStatus/oe:e6fafec8-81fb-4906-9685-77c5282597a0:c997d36f-720f-4f50-a45a-c51c84aae93e?api-version=2021-10-01",
#     "azureml.onlineendpointid": "/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourcegroups/aks-hci2/providers/microsoft.machinelearningservices/workspaces/amlarc-sample-test-ws-eastus/onlineendpoints/tax-model-jiadu"
#   },
#   "provisioning_state": "Succeeded",
#   "resourceGroup": "AKS-HCI2",
#   "scoring_uri": "http://10.156.95.33/api/v1/endpoint/tax-model-jiadu/score",
#   "swagger_uri": "http://10.156.95.33/api/v1/endpoint/tax-model-jiadu/swagger.json",
#   "tags": {},
#   "traffic": {}
# }
# STDERR: WARNING: Command group 'ml online-endpoint' is in preview and under development. Reference and support levels: https://aka.ms/CLI_refstatus

# %%
helpers.run(f"az ml online-deployment create -n blue --endpoint {endpoint} -f {deployment_file} -w {ws.name} -g {ws.resource_group} --all-traffic")
# Out:
# START: az ml online-deployment create -n blue --endpoint tax-model-jiadu -f e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline\deployment.yml -w amlarc-sample-test-ws-eastus -g AKS-HCI2 --all-traffic @ 2021-11-24 15:12:27 (2021-11-24 07:12:27 UTC)
#        using: C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\wbin\az.CMD (Windows 10 on AMD64)
#        cwd: e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline
# {
#   "app_insights_enabled": true,
#   "code_configuration": {
#     "code": {
#       "code_uri": "https://amlarcsamplete7068317793.blob.core.windows.net/azureml-blobstore-e6fafec8-81fb-4906-9685-77c5282597a0/LocalUpload/05472f5107cb927d0bf30d8d3334b32b/pipeline",
#       "id": "azureml:/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourceGroups/AKS-HCI2/providers/Microsoft.MachineLearningServices/workspaces/amlarc-sample-test-ws-eastus/codes/d3665627-62ff-45aa-9b49-369e89805dd3/versions/1",
#       "local_path": "E:\\github\\penorouzi\\AML-Kubernetes-1\\docs\\AKS-HCI\\notebooks\\pipeline",
#       "name": "d3665627-62ff-45aa-9b49-369e89805dd3",
#       "resourceGroup": "AKS-HCI2",
#       "tags": {},
#       "version": "1"
#     },
#     "scoring_script": "score.py"
#   },
#   "endpoint_name": "tax-model-jiadu",
#   "environment": {
#     "conda_file": {
#       "channels": [
#         "anaconda",
#         "conda-forge"
#       ],
#       "dependencies": [
#         "python=3.6.2",
#         {
#           "pip": [
#             "pyarrow",
#             "azureml-defaults"
#           ]
#         },
#         "pandas",
#         "scikit-learn",
#         "numpy=1.19.5"
#       ],
#       "name": "model-env"
#     },
#     "id": "azureml:/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourceGroups/AKS-HCI2/providers/Microsoft.MachineLearningServices/workspaces/amlarc-sample-test-ws-eastus/environments/taxi-model-env/versions/1",
#     "image": "mcr.microsoft.com/azureml/openmpi3.1.2-ubuntu18.04:20210727.v1",
#     "name": "taxi-model-env",
#     "resourceGroup": "AKS-HCI2",
#     "tags": {},
#     "version": "1"
#   },
#   "environment_variables": {},
#   "instance_count": 1,
#   "instance_type": "defaultInstanceType",
#   "model": "azureml:/subscriptions/86204643-5a96-427b-b6bb-b35b2bd6e6ce/resourceGroups/AKS-HCI2/providers/Microsoft.MachineLearningServices/workspaces/amlarc-sample-test-ws-eastus/models/taxi_model/versions/1",
#   "name": "blue",
#   "properties": {},
#   "tags": {},
#   "type": "kubernetes"
# }
# STDERR: WARNING: Command group 'ml online-deployment' is in preview and under development. Reference and support levels: https://aka.ms/CLI_refstatus
# STDERR: Creating or updating online_deployments
# STDERR: Check: endpoint tax-model-jiadu exists
# Uploading pipeline:   0%|          | 0.00/1.17M [00:03<?, ?B/s]
# STDERR: The deployment request amlarc-sample-test-ws-eastus-tax-model-jiadu-2001317 was accepted. ARM deployment URI for reference:
# STDERR: https://ms.portal.azure.com/#blade/HubsExtension/DeploymentDetailsBlade/overview/id/%2Fsubscriptions%2F86204643-5a96-427b-b6bb-b35b2bd6e6ce%2FresourceGroups%2FAKS-HCI2%2Fproviders%2FMicrosoft.Resources%2Fdeployments%2Famlarc-sample-test-ws-eastus-tax-model-jiadu-2001317
# STDERR: Registering code version (d3665627-62ff-45aa-9b49-369e89805dd3 1 )  Done (1s)
# STDERR: Registering environment version (taxi-model-env 1 )  Done (12s)
# STDERR: Creating deployment blue   .................................................................................................  Done (10m 0s)
# STDERR: Total time : 10m 19s
# STDERR: Creating or updating online_endpoints

# %% [markdown]
# ### Test with inputs
#
# A few intances of test data are stored in test_set.csv for convenience of testing.

# %%
# get score_url and access_token from AZ CLI
import helpers
from azureml.core.workspace import Workspace
ws = Workspace.from_config()
cmd = f"az ml online-endpoint show -n {endpoint} -w {ws.name} -g {ws.resource_group}"
properties = helpers.run(cmd, return_output=True, no_output=True)

cmd = f"az ml online-endpoint get-credentials -n {endpoint} -w {ws.name} -g {ws.resource_group}"
credentials = helpers.run(cmd, return_output=True, no_output=True)

print(f"Got endpoint and credentials.")
# Out:
# START: az ml online-endpoint show -n tax-model-jiadu -w amlarc-sample-test-ws-eastus -g AKS-HCI2 @ 2021-11-24 15:24:10 (2021-11-24 07:24:10 UTC)
#        using: C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\wbin\az.CMD (Windows 10 on AMD64)
#        cwd: e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline
# START: az ml online-endpoint get-credentials -n tax-model-jiadu -w amlarc-sample-test-ws-eastus -g AKS-HCI2 @ 2021-11-24 15:24:14 (2021-11-24 07:24:14 UTC)
#        using: C:\Program Files (x86)\Microsoft SDKs\Azure\CLI2\wbin\az.CMD (Windows 10 on AMD64)
#        cwd: e:\github\penorouzi\AML-Kubernetes-1\docs\AKS-HCI\notebooks\pipeline
# Got endpoint and credentials.

# %%
import json
prop_response = json.loads(properties.replace(os.linesep,""))
score_uri = prop_response["scoring_uri"]

cred_response = json.loads(credentials.replace(os.linesep, ""))
access_token = cred_response["accessToken"]

# %%
import json
import pandas as pd

df_raw = pd.read_csv("test_set.csv")
selected_columns = ['pickup_weekday', 'pickup_hour', 'distance', 'passengers', 'vendor']
df = df_raw[selected_columns][:3]
input_np = df.to_numpy()

instances = json.dumps({"data": input_np.tolist()})

import requests
headers = {'Content-Type': 'application/json', 'Authorization': f"Bearer {access_token}"}
r = requests.post(score_uri, data=instances, headers=headers)
print(f"predicted_costs: {r.json()}")

# predicted_costs = service.run(instances)
# print(predicted_costs)
# Out:
# predicted_costs: [8.28844153742305, 22.987604999054316, 7.808465764846998]

# %%
# Real costs

df_raw["cost"][:3].to_numpy().tolist()
# Out:
# [10.5, 20.0, 7.5]
